# %%
import sys
from pathlib import Path

# Get project root (go up ONE level from notebooks/)
project_root = Path().resolve().parent

# Add it to Python path
sys.path.append(str(project_root))

print("Project root:", project_root)
print("Path added:", sys.path[-1])
# Out:
# Project root: C:\Users\phoeb\OneDrive\My Documents\GitHub\biodiversity_dashboard
# Path added: C:\Users\phoeb\OneDrive\My Documents\GitHub\biodiversity_dashboard

# %%
import sys
from pathlib import Path

# Add project root to path
sys.path.append(str(Path().resolve().parents[1]))

from src.db import get_conn
import pandas as pd

with get_conn(read_only=True) as con:
    df = con.execute("SELECT * FROM observations").df()

df.head()

print(df.shape)
df.info()
# Out:
# (880, 40)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                880 non-null    int64
#  1   uuid                              880 non-null    object
#  2   observed_on_string                880 non-null    object
#  3   observed_on                       880 non-null    datetime64[ns]
#  4   time_observed_at                  880 non-null    object
#  5   time_zone                         880 non-null    object
#  6   user_id                           880 non-null    int64
#  7   user_login                        880 non-null    object
#  8   user_name                         857 non-null    object
#  9   created_at                        880 non-null    object
#  10  updated_at                        880 non-null    object
#  11  quality_grade                     880 non-null    object
#  12  license                           835 non-null    object
#  13  url                               880 non-null    object
#  14  image_url                         866 non-null    object
#  15  sound_url                         16 non-null     object
#  16  tag_list                          0 non-null      Int32
#  17  description                       62 non-null     object
#  18  num_identification_agreements     880 non-null    int64
#  19  num_identification_disagreements  880 non-null    int64
#  20  captive_cultivated                880 non-null    bool
#  21  oauth_application_id              439 non-null    float64
#  22  place_guess                       880 non-null    object
#  23  latitude                          880 non-null    float64
#  24  longitude                         880 non-null    float64
#  25  positional_accuracy               730 non-null    float64
#  26  private_place_guess               0 non-null      float64
#  27  private_latitude                  0 non-null      float64
#  28  private_longitude                 0 non-null      float64
#  29  public_positional_accuracy        730 non-null    float64
#  30  geoprivacy                        0 non-null      float64
#  31  taxon_geoprivacy                  254 non-null    object
#  32  coordinates_obscured              880 non-null    bool
#  33  positioning_method                190 non-null    object
#  34  positioning_device                190 non-null    object
#  35  species_guess                     880 non-null    object
#  36  scientific_name                   880 non-null    object
#  37  common_name                       865 non-null    object
#  38  iconic_taxon_name                 879 non-null    object
#  39  taxon_id                          880 non-null    int64
# dtypes: Int32(1), bool(2), datetime64[ns](1), float64(9), int64(5), object(22)
# memory usage: 260.5+ KB

# %%
#Reduce dimensionality by dropping columns with no data, sparse data, low value, or redundancy
cols_to_drop = [
    # No data
    "tag_list", "private_place_guess", "private_latitude",
    "private_longitude", "geoprivacy",

    # Sparse
    "sound_url", "description", "positioning_method",
    "positioning_device", "taxon_geoprivacy",

    # Low value
    "oauth_application_id", "url", "image_url", "license",

    # Redundant
    "observed_on_string", "species_guess"
]

df_reduced = df.drop(columns=cols_to_drop)

df_reduced.shape
